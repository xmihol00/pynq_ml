# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from IPython.display import display, clear_output

# %%
INPUT_WIDTH = 256
INPUT_HEIGHT = 256

train_dir = "../datasets/cats_and_dogs_256x256/train/"
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator()
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(INPUT_WIDTH, INPUT_HEIGHT),
    batch_size=1,
    class_mode='binary',  # binary classification
    #shuffle=False
)

fig, ax = plt.subplots()
for (sample, expected_class) in train_generator:
    print(sample.shape, expected_class)
    ax.clear()
    ax.imshow(sample[0] / 255.0)
    display(fig)
    time.sleep(1)
    clear_output(wait=True)
# Out:
# (1, 256, 256, 3) [1.]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/sdc3/david/projs/pynq_ml/cnn/demo.ipynb Cell 2 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/mnt/sdc3/david/projs/pynq_ml/cnn/demo.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a> ax.imshow(sample[0] / 255.0)
#      <a href='vscode-notebook-cell:/mnt/sdc3/david/projs/pynq_ml/cnn/demo.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a> display(fig)
# ---> <a href='vscode-notebook-cell:/mnt/sdc3/david/projs/pynq_ml/cnn/demo.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a> time.sleep(1)
#      <a href='vscode-notebook-cell:/mnt/sdc3/david/projs/pynq_ml/cnn/demo.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a> clear_output(wait=True)
#
# KeyboardInterrupt:
